# %%
import queue

# %%
t = {
}

# %% [markdown]
# # Modelo Simples (sem considerar o Da e da)

# %%
t["q0"] = {f: (t,"q1") for f,t in zip("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ","ABCDEFGHIJKLMNOPQRSTUVWXYZABCDEFGHIJKLMNOPQRSTUVWXYZ") }
t["q1"] = {f: (t, "q1") for f,t in zip("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ","abcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyz") }
t["q1"].update({" ": (" ","q0")})

# %% [markdown]
# # Modelo considerando Da e De

# %%
t={}

# %%
t["q0"] = {f: (t,"q1") for f,t in zip("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ","ABCDEFGHIJKLMNOPQRSTUVWXYZABCDEFGHIJKLMNOPQRSTUVWXYZ") }
t["q1"] = {f: (t, "q1") for f,t in zip("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ","abcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyz") }
t["q1"].update({" ": (" ","q2")})

t["q2"] = {f: (t, "q1") for f,t in zip("abcefghijklmnopqrstuvwxyzABCEFGHIJKLMNOPQRSTUVWXYZ","ABCEFGHIJKLMNOPQRSTUVWXYZABCEFGHIJKLMNOPQRSTUVWXYZ") }
t["q2"].update({"d": ("", "q3")})
t["q2"].update({"D": ("", "q3")})

t["q3"] = {"a": ("", "q4"), "A": ("", "q4"), "e": ("", "q5"),"E": ("", "q5")}
t["q3"].update({f: ("D"+t,"q1") for f,t in zip("bcdfghijklmnopqrstuvwxyzBCDFGHIJKLMNOPQRSTUVWXYZ","bcdfghijklmnopqrstuvwxyzbcdfghijklmnopqrstuvwxyz") })


t["q4"] = {" ": ("da ", "q0")}
t["q4"].update({f: ("Da"+t, "q1") for f,t in zip("abcdefghijklmnopqrstuwxyz","abcdefghijklmnopqrstuwxyz")})


t["q5"] = {" ": ("de ", "q0")}
t["q5"].update({f: ("De"+t, "q1") for f,t in zip("abcdefghijklmnopqrstuwxyz","abcdefghijklmnopqrstuwxyz")})
t
# Out:
# {'q0': {'a': ('A', 'q1'),
#   'b': ('B', 'q1'),
#   'c': ('C', 'q1'),
#   'd': ('D', 'q1'),
#   'e': ('E', 'q1'),
#   'f': ('F', 'q1'),
#   'g': ('G', 'q1'),
#   'h': ('H', 'q1'),
#   'i': ('I', 'q1'),
#   'j': ('J', 'q1'),
#   'k': ('K', 'q1'),
#   'l': ('L', 'q1'),
#   'm': ('M', 'q1'),
#   'n': ('N', 'q1'),
#   'o': ('O', 'q1'),
#   'p': ('P', 'q1'),
#   'q': ('Q', 'q1'),
#   'r': ('R', 'q1'),
#   's': ('S', 'q1'),
#   't': ('T', 'q1'),
#   'u': ('U', 'q1'),
#   'v': ('V', 'q1'),
#   'w': ('W', 'q1'),
#   'x': ('X', 'q1'),
#   'y': ('Y', 'q1'),
#   'z': ('Z', 'q1'),
#   'A': ('A', 'q1'),
#   'B': ('B', 'q1'),
#   'C': ('C', 'q1'),
#   'D': ('D', 'q1'),
#   'E': ('E', 'q1'),
#   'F': ('F', 'q1'),
#   'G': ('G', 'q1'),
#   'H': ('H', 'q1'),
#   'I': ('I', 'q1'),
#   'J': ('J', 'q1'),
#   'K': ('K', 'q1'),
#   'L': ('L', 'q1'),
#   'M': ('M', 'q1'),
#   'N': ('N', 'q1'),
#   'O': ('O', 'q1'),
#   'P': ('P', 'q1'),
#   'Q': ('Q', 'q1'),
#   'R': ('R', 'q1'),
#   'S': ('S', 'q1'),
# ...

# %%
def parse(inp):
    f = queue.Queue()
    pos=0
    f.put(("q0",pos))
    saida=""
    while(not f.empty()):
        s,pos = f.get()
        
        if(pos >= len(inp)):
            continue
        
        c = inp[pos]
        pos+=1
        if c in t[s]:
            out, nextSt = t[s][c]
            f.put((nextSt, pos))
            saida+=out
    return saida

# %%
parse("guilherme Wachs da silva")
# Out:
# 'Guilherme Wachs da Silva'
